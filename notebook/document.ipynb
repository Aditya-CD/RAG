# %% [markdown]
# ### Data Ingestion

# %%
# Document Structure
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="This is the content of the document.",
    metadata={
        "source": "example_source", 
        "pages": 1,
        "author": "Aditya Gupta", 
        "date": "2024-06-15"
    }
)

# %%
doc
# Out:
# Document(metadata={'source': 'example_source', 'pages': 1, 'author': 'Aditya Gupta', 'date': '2024-06-15'}, page_content='This is the content of the document.')

# %%
# Create a text file
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts = {
    "../data/text_files/python.txt": """Python is a high-level, general-purpose programming language known for its simple and readable syntax.

It is widely used in web development, data science, artificial intelligence, machine learning, automation, and software development.

One of the biggest advantages of Python is that its syntax is easy to understand, which makes it a great language for beginners.

For example, printing something in Python is as simple as:
print("Hello World")

In simple words, Python is a programming language that lets you give instructions to a computer in a simple and readable way.""",

    "../data/text_files/fastapi.txt": """FastAPI is a modern, fast, and lightweight web framework for building APIs with Python.

It is built on top of Starlette for web functionality and Pydantic for data validation. FastAPI uses Python type hints to automatically validate incoming data and generate interactive API documentation.

One of the main advantages of FastAPI is its high performance. It supports asynchronous programming using async and await, making it suitable for applications that need to handle many requests efficiently.

FastAPI automatically generates API documentation using OpenAPI. The documentation can be accessed through interactive interfaces such as Swagger UI and ReDoc.

FastAPI is commonly used for building REST APIs, machine learning APIs, microservices, backend services, and applications that need to communicate with frontend clients.

For example, a simple FastAPI application can define an endpoint that returns a message when a user sends a request.

In simple words, FastAPI allows developers to quickly build high-performance APIs using Python with automatic validation and documentation."""
}

for filepath, content in sample_texts.items():
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(content)

print("Sample text files created successfully.")
# Out:
# Sample text files created successfully.

# %%
# Text Loader
from langchain_community.document_loaders import TextLoader


loader = TextLoader("../data/text_files/python.txt", encoding="utf-8")
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python.txt'}, page_content='Python is a high-level, general-purpose programming language known for its simple and readable syntax.\n\nIt is widely used in web development, data science, artificial intelligence, machine learning, automation, and software development.\n\nOne of the biggest advantages of Python is that its syntax is easy to understand, which makes it a great language for beginners.\n\nFor example, printing something in Python is as simple as:\nprint("Hello World")\n\nIn simple words, Python is a programming language that lets you give instructions to a computer in a simple and readable way.')]

# %%
# Directory Loader
from langchain_community.document_loaders import DirectoryLoader

directory_loader = DirectoryLoader(
    "../data/text_files", 
    glob="*.txt", 
    loader_cls=TextLoader, 
    loader_kwargs={"encoding": "utf-8"}
)
documents = directory_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\fastapi.txt'}, page_content='FastAPI is a modern, fast, and lightweight web framework for building APIs with Python.\n\nIt is built on top of Starlette for web functionality and Pydantic for data validation. FastAPI uses Python type hints to automatically validate incoming data and generate interactive API documentation.\n\nOne of the main advantages of FastAPI is its high performance. It supports asynchronous programming using async and await, making it suitable for applications that need to handle many requests efficiently.\n\nFastAPI automatically generates API documentation using OpenAPI. The documentation can be accessed through interactive interfaces such as Swagger UI and ReDoc.\n\nFastAPI is commonly used for building REST APIs, machine learning APIs, microservices, backend services, and applications that need to communicate with frontend clients.\n\nFor example, a simple FastAPI application can define an endpoint that retu
# ...

# %%
for content in documents:
    print(f"Document {documents.index(content)+1}: {content.page_content}")
    print(f"Metadata: {content.metadata}")
    print("\n")
# Out:
# Document 1: FastAPI is a modern, fast, and lightweight web framework for building APIs with Python.
#
# It is built on top of Starlette for web functionality and Pydantic for data validation. FastAPI uses Python type hints to automatically validate incoming data and generate interactive API documentation.
#
# One of the main advantages of FastAPI is its high performance. It supports asynchronous programming using async and await, making it suitable for applications that need to handle many requests efficiently.
#
# FastAPI automatically generates API documentation using OpenAPI. The documentation can be accessed through interactive interfaces such as Swagger UI and ReDoc.
#
# FastAPI is commonly used for building REST APIs, machine learning APIs, microservices, backend services, and applications that need to communicate with frontend clients.
#
# For example, a simple FastAPI application can define an endpoint that returns a message when a user sends a request.
#
# ...

# %%
content
# Out:
# Document(metadata={'source': '..\\data\\text_files\\python.txt'}, page_content='Python is a high-level, general-purpose programming language known for its simple and readable syntax.\n\nIt is widely used in web development, data science, artificial intelligence, machine learning, automation, and software development.\n\nOne of the biggest advantages of Python is that its syntax is easy to understand, which makes it a great language for beginners.\n\nFor example, printing something in Python is as simple as:\nprint("Hello World")\n\nIn simple words, Python is a programming language that lets you give instructions to a computer in a simple and readable way.')

# %%
from langchain_community.document_loaders import PyMuPDFLoader

directory_loader = DirectoryLoader(
    "../data/pdf", 
    glob="*.pdf", 
    loader_cls=PyMuPDFLoader, 
    loader_kwargs={"password": None}
)

pdf_documents = directory_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-09-18T09:48:57+00:00', 'source': '..\\data\\pdf\\docker.pdf', 'file_path': '..\\data\\pdf\\docker.pdf', 'total_pages': 4, 'format': 'PDF 1.4', 'title': 'Introduction to Docker', 'author': '(anonymous)', 'subject': '(unspecified)', 'keywords': '', 'moddate': '2026-09-18T09:48:57+00:00', 'trapped': '', 'modDate': "D:20260918094857+00'00'", 'creationDate': "D:20260918094857+00'00'", 'page': 0}, page_content='Introduction to Docker\n1. What is Docker?\nDocker is an open-source platform that allows developers to package applications, along with all of\ntheir dependencies, into standardized units called containers. A container includes everything an\napplication needs to run - code, runtime, system tools, libraries, and configuration files - so it behaves\nthe same way regardless of where it is deployed.\nDocker was first released in 2013 and quickly became the standard
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
